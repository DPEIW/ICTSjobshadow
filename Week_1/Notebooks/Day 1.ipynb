# %% [markdown]
# plot a graph using numpy and matplotlib as a task
#
# To start with,
# y = f(t)
# f(t) = 5t + 6
#
# t ∈ [-1, 1; 2000]

# %%
import numpy as np
import matplotlib.pyplot as plt

def equation(x):
  return (5 * x) + 6

x = np.linspace(-1, 1, 2000)

y = equation(x)

plt.plot(x, y)

# %%
np.linspace(-1, 1, 1000)
# Out:
# array([-1.        , -0.997998  , -0.995996  , -0.99399399, -0.99199199,
#        -0.98998999, -0.98798799, -0.98598599, -0.98398398, -0.98198198,
#        -0.97997998, -0.97797798, -0.97597598, -0.97397397, -0.97197197,
#        -0.96996997, -0.96796797, -0.96596597, -0.96396396, -0.96196196,
#        -0.95995996, -0.95795796, -0.95595596, -0.95395395, -0.95195195,
#        -0.94994995, -0.94794795, -0.94594595, -0.94394394, -0.94194194,
#        -0.93993994, -0.93793794, -0.93593594, -0.93393393, -0.93193193,
#        -0.92992993, -0.92792793, -0.92592593, -0.92392392, -0.92192192,
#        -0.91991992, -0.91791792, -0.91591592, -0.91391391, -0.91191191,
#        -0.90990991, -0.90790791, -0.90590591, -0.9039039 , -0.9019019 ,
#        -0.8998999 , -0.8978979 , -0.8958959 , -0.89389389, -0.89189189,
#        -0.88988989, -0.88788789, -0.88588589, -0.88388388, -0.88188188,
#        -0.87987988, -0.87787788, -0.87587588, -0.87387387, -0.87187187,
# ...

# %% [markdown]
# just testing other functions as well to get the hang of numpy, this example is a quadratic eqn

# %%
import numpy as np
import matplotlib.pyplot as plt

def equation(x):
  return (5 * (x ** 2)) + (6 * x) + 7

x = np.linspace(-10, 10, 10000)

y = equation(x)

plt.plot(x, y)

# %%
print(np.e)
#gamma gives damping factor     
#omega decides how fast the signal oscillates
# Out:
# 2.718281828459045

# %% [markdown]
# Black hole quasi - normal modes.
# Black holes ring down based on the damped sinusoid function.
# "A damped sinusoid, or damped sine wave, is a sinusoidal function that's used in engineering and science to model situations where a harmonic oscillator loses energy faster than it's supplied. A damped sinusoid is a smooth, periodic oscillation with an amplitude that approaches zero as time increases." (wikipedia)
#
# Equation is given by:
#
# ![image.png](attachment:image.png)
#
# This is how a black hole settles down even if you disturb it slightly.
#
# We can identify the spin and mass of a black hole based on this graph

# %%
import numpy as np
import matplotlib.pyplot as plt

gamma0 = 2
omega0 = 24
omega1 = 48

def equation(x, omega, gamma):
  return (np.exp((-gamma)*x) * np.cos(omega * x))

x = np.linspace(0, 1, 1000)

y0 = equation(x, omega0, gamma0)
y1 = equation(x, omega1, gamma0)

plt.plot(x, y0) 
plt.plot(x, y1)

# %% [markdown]
# Plotting against the log of the function
#
# ![image.png](attachment:image.png)
#
# which is

# %%
#a = 2
#b = 2

gamma0 = 2
omega0 = 24

def equation(x, omega, gamma):
  #return (np.e ** ((a)*x) * np.cos(b * x))
  return (np.exp((-gamma)*x) * np.cos(omega * x))

x = np.linspace(-1, 1, 1000)

y = equation(x, omega0, gamma0)

plt.plot(x, abs(y))  
plt.show()

plt.semilogy(x, abs(y))

# %%
#generate random numbers from a normal distribution using python and add it to the signal 
#change amplitude of the wave as well 
#n0 is noise, add n0 to the Array 
#trying to mimic noise in detectors as we don't get signals like this
#warmup exercise for the actual data used

# %% [markdown]
# Generate random numbers from a normal distribution using python and add it to the signal. Change amplitude of the wave as well
#
# n0 is noise, add n0 to the Array. Trying to mimic noise in detectors as we don't get signals like this. Warmup exercise for the actual data used

# %%
#Day 2 at home

x_linear = np.linspace(-1, 1, 1000)
#y_random = np.random.randint(-100, 100, size=(1000))
y_random = (np.random.rand(1000)-0.5)

plt.plot(x_linear, y_random)
plt.plot(x,y0)

# %% [markdown]
# Now we will add y0 value to the random floats (generating noise) so we can hide the wave

# %%
np.random.rand?
# Out:
# Docstring:
# rand(d0, d1, ..., dn)
#
# Random values in a given shape.
#
# .. note::
#     This is a convenience function for users porting code from Matlab,
#     and wraps `random_sample`. That function takes a
#     tuple to specify the size of the output, which is consistent with
#     other NumPy functions like `numpy.zeros` and `numpy.ones`.
#
# Create an array of the given shape and populate it with
# random samples from a uniform distribution
# over ``[0, 1)``.
#
# Parameters
# ----------
# d0, d1, ..., dn : int, optional
#     The dimensions of the returned array, must be non-negative.
#     If no argument is given a single Python float is returned.
#
# Returns
# -------
# out : ndarray, shape ``(d0, d1, ..., dn)``
#     Random values.
#
# See Also
# --------
# random
#
# Examples
# --------
# >>> np.random.rand(3,2)
# array([[ 0.14022471,  0.96360618],  #random
#        [ 0.37601032,  0.25528411],  #random
#        [ 0.49313049,  0.94909878]]) #random
# ...

# %%
help(np.random.rand)
# Out:
# Help on built-in function rand:
#
# rand(...) method of numpy.random.mtrand.RandomState instance
#     rand(d0, d1, ..., dn)
#
#     Random values in a given shape.
#
#     .. note::
#         This is a convenience function for users porting code from Matlab,
#         and wraps `random_sample`. That function takes a
#         tuple to specify the size of the output, which is consistent with
#         other NumPy functions like `numpy.zeros` and `numpy.ones`.
#
#     Create an array of the given shape and populate it with
#     random samples from a uniform distribution
#     over ``[0, 1)``.
#
#     Parameters
#     ----------
#     d0, d1, ..., dn : int, optional
#         The dimensions of the returned array, must be non-negative.
#         If no argument is given a single Python float is returned.
#
#     Returns
#     -------
#     out : ndarray, shape ``(d0, d1, ..., dn)``
#         Random values.
#
#     See Also
#     --------
#     random
#
#     Examples
#     --------
# ...

# %%
x_linear = np.linspace(-1, 1, 1000)
y_comb = y0 + (np.random.rand(1000)*20) 
#change the multiplied value to make it more/less hidden

plt.plot(x_linear, y_comb)
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\drpro\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\drpro\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\drpro\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
# ...

# %% [markdown]
# np.random.randn takes values from the normal
